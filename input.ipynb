# %% [markdown]
# <a href="https://colab.research.google.com/github/felipecsousa2000/teste123456/blob/master/input.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nome = input("Digite seu nome: ")
print("Seu nome é: ", nome)
# Out:
# Digite seu nome: Pedro
# Seu nome é:  Pedro

# %%
num1 = int(input("Digite seu número: "))
num2= int(input("Digite seu outro número: "))
soma = num1 + num2
print("O resultado será:", soma)
# Out:
# Digite seu número: 15
# Digite seu outro número: 30
# O resultado será: 45

# %%
num1 = int(input("Digite um número: "))
num2 = int(input("Digite um número: "))
sub = num1 / num2
print(sub)
# Out:
# Digite um número: 15
# Digite um número: 5
# 3.0

# %%
nome= input("Digite o seu nome: ")
print("Meu nome é :", nome)
print(f"Olá {nome} Seja Bem vindo")
# Out:
# Digite o seu nome: felipe
# Meu nome é : felipe
# Olá felipe Seja Bem vindo
